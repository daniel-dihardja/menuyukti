# %%
import json
import analytics.analytics_util as au

analytic = au.build_analytic_from_excel("../apps/web/reports/Sales_Recapitulation_Detail_Report_Jan-Mar_2025.xlsx", name="Test Analytic")
print(json.dumps(analytic, indent=2, default=str))
# Out:
# {
#   "name": "Test Analytic",
#   "startDate": "2025-01-02 08:25:56",
#   "endDate": "2025-03-28 12:39:18",
#   "ordersCount": 1779,
#   "revenueTotal": 70364399.9995,
#   "maxOrderItems": 55.0,
#   "avgOrderItems": 2.35469364811692,
#   "minOrderItems": 1.0,
#   "minOrderRevenue": 0.0,
#   "maxOrderRevenue": 1221000.0,
#   "avgOrderRevenue": 39552.78246177628,
#   "orders": [
#     {
#       "billNumber": "SCM01202501020001",
#       "salesNumber": "SCM01202501020001",
#       "datetime": "2025-01-02 08:25:56",
#       "items": [
#         {
#           "menuCode": null,
#           "menuName": "Es Kopi Susu Aren",
#           "category": "Unknown",
#           "subcategory": null,
#           "price": 24000.0,
#           "qty": 1.0,
#           "netTotal": 24000.0
#         }
#       ]
#     },
#     {
#       "billNumber": "SCM01202501020002",
#       "salesNumber": "SCM01202501020002",
#       "datetime": "2025-01-02 08:55:59",
#       "items": [
#         {
# ...

# %%
au.test_hot_reload()
# Out:
# 'UPDATED SUCCESSFULLY'
